# %% [markdown]
# <a href="https://colab.research.google.com/github/2heeng/pythonBasic/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A7%911_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
requests.get('https://plusdeal.naver.com/?sort=1&NaPm=ct%3Dlvovyr4e%7Cci%3Dshoppingwindow%7Ctr%3Dnsh%7Chk%3D6c094bdf086aa668f6050cbc4f443492aa36691a%7Ctrx%3D')
# Out:
# <Response [200]>

# %%
resp_status_code=requests.get('https://plusdeal.naver.com/?sort=1&NaPm=ct%3Dlvovyr4e%7Cci%3Dshoppingwindow%7Ctr%3Dnsh%7Chk%3D6c094bdf086aa668f6050cbc4f443492aa36691a%7Ctrx%3D')

# %%
BeautifulSoup(resp_status_code.content,'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 BeautifulSoup(resp_status_code.content,'lxml')
#
# NameError: name 'BeautifulSoup' is not defined

# %%
from bs4 import BeautifulSoup

# %%
BeautifulSoup(resp_status_code.content,'lxml')
# Out:
# <!DOCTYPE html>
# ...

# %%
bs=BeautifulSoup(resp_status_code.content,'lxml')

# %%
bs.find_all('div','strong')
# Out:
# []

# %%
#위에거 실패
