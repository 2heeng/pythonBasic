# %% [markdown]
# <a href="https://colab.research.google.com/github/2heeng/pythonBasic/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A7%91_%EB%8C%93%EA%B8%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url="https://n.news.naver.com/mnews/article/032/0003294257"

# %%
resp_status_code=requests.get(url)

# %%
resp_status_code
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
BeautifulSoup(resp_status_code.content,'lxml')
# Out:
# <!DOCTYPE html>
# <html data-useragent="python-requests/2.31.0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="이재명 “윤 대통령, 범인 아니니 특검 거부하지 않을 것”" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/032/0003294257" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/032/2024/05/03/0003294257_001_20240503101503486.jpeg?type=w800" property="og:image"/>
# <meta content="더불어민주당은 3일 윤석열 대통령이 전날 국회를 통과한 해병대 채 상병 특검법안에 거부권(재의요구권) 행사를 시사하자 “특검을 거부하는 자가 범인”이라고 압박했다. 민주당은 대통령이 특검에 거부권을 행사하면 “더 큰" property="og:description"/>
# <meta content="경향신문 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# ...

# %%
bs=BeautifulSoup(resp_status_code.content,'lxml')

# %%
bs.find_all('div',{'class':'u_cbox_text_wrap'})
# Out:
# []

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
# !pip install selenium
# Out:
# ...
#   Obtaining dependency information for selenium from https://files.pythonhosted.org/packages/04/4d/a6e8afd65b87372e275eb612d564ec68f79195e9b7e27004a3b2cce69686/selenium-4.20.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio~=0.17 from https://files.pythonhosted.org/packages/17/c9/f86f89f14d52f9f2f652ce24cb2f60141a51d087db1563f3fba94ba07346/trio-0.25.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for trio-websocket~=0.9 from https://files.pythonhosted.org/packages/48/be/a9ae5f50cad5b6f85bd2574c2c923730098530096e170c1ce7452394d7aa/trio_websocket-0.11.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for typing_extensions>=4.9.0 from https://files.pythonhosted.org/packages/01/f3/936e209267d6ef7510322191003885de524fc48d1b43269810cd589ceaf5/typing_extensions-4.11.0-py3-none-any.whl.metadata
# ...

# %%
import selenium

# %%
#help(selenium)

# %%
from selenium.webdriver import Chrome

# %%
#help(Chrome)

# %%
driver_path='E:/tool/chromedriver_win32/chromedriver.exe'

# %%
driver=Chrome()

# %%
url='https://n.news.naver.com/mnews/article/032/0003294257'

# %%
driver.get(url)

# %%
import time

# %%
for i in range(5,0,-1):
    print(i)
    time.sleep(1)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
#help(driver.find_element)

# %%
from selenium.webdriver.common.by import By

# %%
for i in range(10):
    clickable = driver.find_element(By.CLASS_NAME,'u_cbox_btn_more')
    clickable.click()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[30], line 3
#       1 for i in range(10):
#       2     clickable = driver.find_element(By.CLASS_NAME,'u_cbox_btn_more')
# ----> 3     clickable.click()
#       4     time.sleep(1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
# ...

# %%
from bs4 import BeautifulSoup

# %%
driver.page_source
# Out:
# '<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"><head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n\t\t<meta property="og:title" content="이재명 “윤 대통령, 범인 아니니 특검 거부하지 않을 것”">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/032/0003294257">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/032/2024/05/03/0003294257_001_20240503101503486.jpeg?type=w800">\n\t\t<meta property="og:description" content="더불어민주당은 3일 윤석열 대통령이 전날 국회를 통과한 해병대 채 상병 특검법안에 거부권(재의요구권) 행사를 시사하자 “특검을 거부하는 자가 범인”이라고 압박했다. 민주당은 대통령이 특검에 거부권을 행사하면 “더 큰">\n\t\t<meta property="og:article:author" content="경향신문 | 네이버">\n\t\t<meta name="twitter:card" content
# ...

# %%
bs=BeautifulSoup(driver.page_source,'lxml')

# %%
li=bs.find_all('span',{'class':'u_cbox_contents'})

# %%
for i in li:
    print(i.text)
# Out:
# ㅋㅋㅋ 역시 전과4범답도다!아픈곳만 골라서 패는구나!!
# 방통위,방심위는 국정조사를 해야한다
# 특검 수용하면,,,윤석열이는,,,감방행,,,~범인~
# 이참에 공수처 폐지하자!
# 이죄명,  넌 전과자이면서 범죄자인데도 그게 말이되냐? 리짜이밍~~셰셰!
# 특검  막아라  그래야산다  국민들속이는거는  담화로
# 범인이 아니니 특검 거부하지 않을꺼라는건 거부하면 범행을 자인하는건가?  바로 체포영장 집행이 불가능한건데~~대통령은 임기중 형사소추를 받지 않는데 어카지?  특검 거부하면 탄핵절차 진행?
# 역시 이재명대통령은 멋져!  거부하면 범인이네. 그럼 바로 탄핵!!!
# 경찰도 수사 중.. 공수처도 수사 중... 특검도 수사 중..  경찰, 공수처는 뭐하러 수사하니... 모든 사건을  특검에서 하지..
# 질질 끌려 내려와 비참한 최후를 맞이하는 부부가 될거 같다. 국짐당 정신 차려라. 지방선거. 대선 줄줄이 국민심판이 기다린다!
# 킹재명 룬두창 너범인아니야 거부하지마 ㅋ
# 정치9단 윤석열이 순진하고 어리버리한 박근혜와 같은줄 아냐?
# 범죄자들이 특검운운하고 있네 뭐 저리뻔뻔하냐. 지지하는놈들은 뭐 노답인생들이고
# 석열이가 잘도 찬성하겠다ㅋㅋㅋ
# 역대 어느 대통령 보다 비겁하지 총선 폭망하고도 사의 표명한 비서실장 통해 몇마디 전달한게 전부잖아 말뒤집기 전문이기도 하고 특검 거부하는 자가 범인이라고 누가 말했냐?
# 특검 거부 최초 기록은 노무현이 가지고 있음.
# 사지분간  못하더니 개망신인겨  ?  치욕의 나날들이  ?
# 지난4년 태양광 비리 하나도 남김없이. 전부 재조사하는것이 정답
# 그네 특검으로 총장에 대통 되고선 지는 거부하는 나쁜
# 특검 거부하면 범인 인정 ㅋㅋㅋ
# 그러는 너는 국민세금 법카 쓴적없으니까 재판을 거부하지.않겠지???
# 거부의 왕~ 난 범인이다!
# 거부하면 범인 인증~탄핵가자
# 혜경이 法카  特檢法 發議해봐라. 2찢滓皿아
# 그럼 이재명은 대장동 범인이다????  ㅎㅎㅎㅎㅎㅎㅎ
# ...

# %%
#파일로 저장
with open('C:/ex/py/reply.txt','w',encoding='utf-8') as f:
    for i in li:
        f.write(i.text)
